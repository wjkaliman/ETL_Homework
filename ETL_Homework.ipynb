# %%
# Extract section
Dataset 1 from folder DOT_dataset. This is the link https://www.kaggle.com/usdot/flight-delays?select=flights.csv-
Dataset 2 from folder DOT_dataset. This is the link https://www.kaggle.com/usdot/flight-delays?select=flights.csv-
Dataset 3 from folder Yuanyu_dataset.This is the link: https://www.kaggle.com/yuanyuwendymu/airline-delay-and-cancellation-data-2009-2018  I used the year 2015.
Dataset 4 from folder Yuanyu_dataset.This is the link: https://www.kaggle.com/anshuls235/airline-delay-causes

# %%
import numpy as np
import pandas as pd

# %%
# Name and Location of the CSV file
file = 'DOT_dataset/datasets_810_1496_airlines.csv'
# Name and Location of the CSV file
file1 = 'DOT_dataset/datasets_810_1496_airports.csv'
# Name and Location of the CSV file
file2 = 'Yuanyu_dataset/2015.csv'
# Name and Location of the CSV file
file3 = 'Sharma_dataset/894233989_32020_056_airline_delay_causes.csv'

# %%
airline = pd.read_csv(file, encoding="ISO-8859-1")
airports = pd.read_csv(file1, encoding="ISO-8859-1")
year = pd.read_csv(file2, encoding="ISO-8859-1")
delay = pd.read_csv(file3, encoding="ISO-8859-1")

# %%
print(airline.head())
print(airports.head())
print(year.head())
print(delay.head())
# Out:
#   IATA_CODE                 AIRLINE
# 0        UA   United Air Lines Inc.
# 1        AA  American Airlines Inc.
# 2        US         US Airways Inc.
# 3        F9  Frontier Airlines Inc.
# 4        B6         JetBlue Airways
#   IATA_CODE                              AIRPORT         CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport    Allentown    PA     USA
# 1       ABI             Abilene Regional Airport      Abilene    TX     USA
# 2       ABQ    Albuquerque International Sunport  Albuquerque    NM     USA
# 3       ABR            Aberdeen Regional Airport     Aberdeen    SD     USA
# 4       ABY   Southwest Georgia Regional Airport       Albany    GA     USA
#
#    LATITUDE  LONGITUDE
# 0  40.65236  -75.44040
# 1  32.41132  -99.68190
# 2  35.04022 -106.60919
# 3  45.44906  -98.42183
# 4  31.53552  -84.19447
#       FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0  2015-01-01         NK                195    MCO  FLL          2147
# ...

# %% [markdown]
# # Transforming Data

# %%
#looking to see what airlines are on the dataset.
airline["IATA_CODE"].unique()
# Out:
# array(['UA', 'AA', 'US', 'F9', 'B6', 'OO', 'AS', 'NK', 'WN', 'DL', 'EV',
#        'HA', 'MQ', 'VX'], dtype=object)

# %%
year["OP_CARRIER"].unique()
# Out:
# array(['NK', 'MQ', 'OO', 'EV', 'HA', 'UA', 'US', 'VX', 'WN', 'B6', 'F9',
#        'AA', 'AS', 'DL'], dtype=object)

# %%
year.head()
# Out:
#       FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0  2015-01-01         NK                195    MCO  FLL          2147
# 1  2015-01-01         NK                197    LGA  FLL          1050
# 2  2015-01-01         NK                198    FLL  MCO           700
# 3  2015-01-01         NK                199    IAH  LAS          2240
# 4  2015-01-01         NK                200    IAH  ORD           623
#
#    DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  ...  CRS_ELAPSED_TIME  \
# 0    2143.0       -4.0      15.0      2158.0  ...              63.0
# 1    1104.0       14.0      20.0      1124.0  ...             194.0
# 2     712.0       12.0      19.0       731.0  ...              57.0
# 3    2251.0       11.0       8.0      2259.0  ...             196.0
# 4     620.0       -3.0      15.0       635.0  ...             152.0
#
#    ACTUAL_ELAPSED_TIME  AIR_TIME  DISTANCE  CARRIER_DELAY  WEATHER_DELAY  \
# ...

# %%
airports.head()
# Out:
#   IATA_CODE                              AIRPORT         CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport    Allentown    PA     USA
# 1       ABI             Abilene Regional Airport      Abilene    TX     USA
# 2       ABQ    Albuquerque International Sunport  Albuquerque    NM     USA
# 3       ABR            Aberdeen Regional Airport     Aberdeen    SD     USA
# 4       ABY   Southwest Georgia Regional Airport       Albany    GA     USA
#
#    LATITUDE  LONGITUDE
# 0  40.65236  -75.44040
# 1  32.41132  -99.68190
# 2  35.04022 -106.60919
# 3  45.44906  -98.42183
# 4  31.53552  -84.19447
